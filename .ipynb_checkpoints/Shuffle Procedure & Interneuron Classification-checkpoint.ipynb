# %% [markdown]
# # Setup

# %%
''' magic 4u'''
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
'''Get stuff you need'''
import numpy as np
from tqdm import tnrange
from tqdm.notebook import tqdm as tdqm
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
from matplotlib import gridspec
from scipy.interpolate import interp1d
from scipy.ndimage import gaussian_filter1d
from scipy import stats
import scipy.io
from IPython.core.debugger import set_trace
import scipy.ndimage.filters as filt
import pandas as pd
import seaborn as sns
import math

from pipeline import get_data as get
from pipeline import process_spikes as ps

from sklearn.cluster import KMeans
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper
from sklearn.metrics import silhouette_samples, silhouette_score

from statsmodels.tsa.stattools import acf
from scipy.signal import find_peaks
from itertools import combinations

# %%
''' Define some functions for later '''
def tuning_curve_bytrial(x, trial, Y, dt, b, smooth=True, normalize=False, occupancy=True):
    '''
    Params
    ------
    x : ndarray
        variable of interest by observation; shape (n_obs, )
    trial : ndarray
        trial num for each observation; shape (n_obs, )
    Y : ndarray
        spikes per observation; shape (n_obs, n_cells)
    dt : int
        time per observation in seconds
    b : int
        bin size
    smooth : bool
        apply gaussian filter to firing rate; optional, default is True
    normalize : bool
        normalize the firing rate of each cell such that its max FR is 1, min is 0;
        optional, default is False
    occupancy : bool
        return occupancy (dwell time in each bin); optional, default is True

    Returns
    -------
    firing_rate : ndarray
        binned firing rate for each trial for each cell; shape (n_trials, n_bins, n_cells)
    centers : ndarray
        center of each bin
    occ : ndarray
       dwell time in each bin; shape (n_bins, n_cells)
    '''
    edges = np.arange(0, np.max(x) + b, b)
    centers = (edges[:-1] + edges[1:])/2
    b_idx = np.digitize(x, edges)
    if np.max(x) == edges[-1]:
        b_idx[b_idx==np.max(b_idx)] = np.max(b_idx) - 1
    unique_bdx = np.unique(b_idx)

    # find FR in each bin
    firing_rate = np.zeros((np.unique(trial).shape[0], unique_bdx.shape[0], Y.shape[1]))
    occ = np.zeros((np.unique(trial).shape[0], unique_bdx.shape[0], Y.shape[1]))
    for j in range(unique_bdx.shape[0]):
        idx1 = (b_idx == unique_bdx[j])
        for i, t in enumerate(np.unique(trial)):
            idx = idx1 & (trial == t)
            if np.sum(idx)==0:
                print('warning: zero occupancy!')
                firing_rate[i, j, :] = firing_rate[i, j-1, :]
                occ[i, j, :] = 0
            else:    
                spike_ct = np.sum(Y[idx, :], axis=0)
                occupancy = dt * np.sum(idx)
                occ[i, j, :] = occupancy
                firing_rate[i, j, :] = spike_ct / occupancy
    if smooth:
        firing_rate = gaussian_filter1d(firing_rate, 2, axis=1, mode='wrap')

    if normalize:
        for c in range(firing_rate.shape[1]):
            firing_rate[:, :, c] = (firing_rate[:, :, c] - np.min(firing_rate[:, :, c]))/np.max(firing_rate[:, :, c] - np.min(firing_rate[:, :, c]))
    
    if occupancy:
        return firing_rate, centers, occ
    else: 
        return firing_rate, centers
    
def find8adjacentElements(test_list):
    ''' 
    Params
    ------
    test_list : ndarray
        1d array to be sorted
    
    Returns
    -------
    neighbors : list
        nested list where each element is a list of 8 adjacent elements to the element with the same 
        index in test_list, adjusting for the first and last four elements and not including 
    '''
    
    neighbors = []
    for idx, ele in enumerate(test_list):
    # Checking for all cases to append
        if idx == 0:
            neighbors.append(test_list[(idx+1):(idx + 9)])
        elif idx == 1:
            neighbors.append(np.concatenate((test_list[(idx - 1)],test_list[(idx+1):(idx + 8)]),axis=None))
        elif idx == 2:
            neighbors.append(np.concatenate((test_list[:idx],test_list[(idx+1):(idx + 7)]),axis=None))
        elif idx == 3:
            neighbors.append(np.concatenate((test_list[:idx],test_list[(idx+1):(idx + 6)]),axis=None))
        elif idx == len(test_list) - 1:
            neighbors.append(np.concatenate((test_list[(idx-8):idx]),axis=None))                     
        elif idx == len(test_list) - 2:
            neighbors.append(np.concatenate((test_list[(idx-7):idx],test_list[(idx + 1):]),axis=None))
        elif idx == len(test_list) - 3:
            neighbors.append(np.concatenate((test_list[(idx-6):idx],test_list[(idx + 1):]),axis=None))
        elif idx == len(test_list) - 4:
            neighbors.append(np.concatenate((test_list[(idx-5):idx],test_list[(idx + 1):]),axis = None))
        else:
            neighbors.append(np.concatenate((test_list[(idx - 4):idx],test_list[(idx+1):(idx + 5)]),axis=None))
    return neighbors 

    return (phi ** np.arange(nt)) * sigma2 / (1 - phi ** 2)

def autocorr(x,lags):
    '''numpy.correlate'''
    mean=x.mean()
    var=np.var(x)
    xp=x-mean
    corr=np.correlate(xp,xp,'full')[len(x)-1:]/var/len(x)

    return corr[:len(lags)]

def find(x):
    return x.nonzero()[0]

# %%
''' Load in Animal Metadata '''

animalmeta = pd.read_csv('C:/Users/Python/Desktop/Dryad/MouseMetadata.csv') # adjust path name

# define some useful lists of animals based on metadata
all_aged_mice = np.array(animalmeta.loc[(animalmeta.Age_Group == 3),'Animal_ID'])
all_MA_mice = np.array(animalmeta.loc[(animalmeta.Age_Group == 2),'Animal_ID'])
all_young_mice = np.array(animalmeta.loc[(animalmeta.Age_Group == 1),'Animal_ID'])

cohorta_mice = np.array(animalmeta.loc[(animalmeta.Cohort == 'A'),'Animal_ID'])
cohortb_mice = np.array(animalmeta.loc[(animalmeta.Cohort == 'B'),'Animal_ID'])
cohortc_mice = np.array(animalmeta.loc[(animalmeta.Cohort == 'C'),'Animal_ID'])
cohortd_mice = np.array(animalmeta.loc[(animalmeta.Cohort == 'D'),'Animal_ID'])

RF_aged_mice = np.array(animalmeta.loc[(animalmeta.Age_Group == 3) & (animalmeta.Task == 'RF'),'Animal_ID'])
RF_young_mice = np.array(animalmeta.loc[(animalmeta.Age_Group == 1) & (animalmeta.Task == 'RF'),'Animal_ID'])
SM_aged_mice = np.array(animalmeta.loc[(animalmeta.Age_Group == 3) & (animalmeta.Task == 'SM'),'Animal_ID'])
SM_MA_mice = np.array(animalmeta.loc[(animalmeta.Age_Group == 2) & (animalmeta.Task == 'SM'),'Animal_ID'])
SM_young_mice = np.array(animalmeta.loc[(animalmeta.Age_Group == 1) & (animalmeta.Task == 'SM'),'Animal_ID'])

all_female_mice = np.array(animalmeta.loc[(animalmeta.Sex == 'F'),'Animal_ID'])
all_male_mice = np.array(animalmeta.loc[(animalmeta.Sex == 'M'), 'Animal_ID'])
RF_female_mice = np.array(animalmeta.loc[(animalmeta.Sex == 'F') & (animalmeta.Task == 'RF'),'Animal_ID'])
RF_male_mice = np.array(animalmeta.loc[(animalmeta.Sex == 'M') & (animalmeta.Task == 'RF'),'Animal_ID'])
SM_female_mice = np.array(animalmeta.loc[(animalmeta.Sex == 'F') & (animalmeta.Task == 'SM'),'Animal_ID'])
SM_male_mice = np.array(animalmeta.loc[(animalmeta.Sex == 'M') & (animalmeta.Task == 'SM'),'Animal_ID'])

animalmeta.head()
# Out:
#   Animal_ID Task Cohort  Probe_Control Sex   Sac_Date Frozen_Hemisphere  \
# 0        A3   RF      A              0   F  1/27/2021                 R
# 1        A4   RF      A              0   F  1/27/2021                 R
# 2        A5   RF      A              0   F   4/6/2021                 L
# 3        A6   RF      A              0   F   4/6/2021                 R
# 4        A7   RF      A              0   F  4/19/2021                 L
#
#          DOB  Age_WholeMonth  Age_ExtraDays  Age_Month  Aged_Days  Age_Group  \
# 0  4/23/2019              21              4     21.217        645          3
# 1  4/23/2019              21              4     21.217        645          3
# 2  4/23/2019              23             14     23.487        714          3
# 3  4/23/2019              23             14     23.487        714          3
# 4  5/29/2019              22             21     22.730        691          3
#
#    Behavior_Sessions  Neural_Sessions
# 0                  6                6
# 1                  6                6
# 2                  6                6
# 3                  6                6
# 4                  6                6

# %%
''' Complete List of Mice & Neural Data Sessions '''
all_mice = np.array(animalmeta.Animal_ID)
print(all_mice)

#list of session IDs in order of mouse names
all_sessions = ([['0122_record1','0123_record2','0124_record3','0125_record4','0126_record5','0127_record6'], #A3
             ['0122_record1','0123_record2','0124_record3','0125_record4','0126_record5','0127_record6'], #A4
             ['0401_record1','0401_record2b','0403_record3','0404_record4','0405_record5','0406_record6'], #A5
             ['0401_record1','0402_record2','0403_record3','0404_record4','0405_record5','0406_record6'], #A6
             ['0414_record1','0415_record2','0416_record3','0417_record4','0418_record5','0419_record6'], #A7
             ['1024_record1','1025_record2','1026_record3','1027_record4','1028_record5_2'], #Y2; _6 excluded
             ['1016_record1','1019_record3','1020_record4','1021_record5','1022_record6'], #Y3; _2 not collected
             ['1114_record1','1115_record2','1116_record3','1117_record4','1118_record5','1119_record6'], # end cohort A
             ['051822_record1','051922_record2','052022_record3','052122_record4','052222_record5','052322_record6'],
             ['050522_record1','050622_record2','050722_record3','050822_record4','050922_record5','051022_record6'],
             ['050522_record1','050622_record2','050722_record3','050822_record4','051022_record6'], #Y11_5 not collected
             ['062222_record3','062322_record4','062522_record5'], #Y16_1 & 2 not collected, _6 neural excluded
             ['062822_record1','062922_record2','063022_record3','070122_record4','070222_record5','070322_record6'],
             ['062022_record1','062122_record2','062222_record3','062322_record4','062522_record5','062622_record6'],
             ['062822_record1','062922_record2','063022_record3','070122_record4','070222_record5','070322_record6'], 
             ['051922_record2','052022_record3'], # end cohort B; Y9 051822_1 excluded; _2 and &_3 excluded from behavior
             ['083022_record1','083122_record2','090122_record3'], 
             ['083022_record1','083122_record2','090122_record3','090222_record4','090322_record5','090422_record6'],
             ['083022_record1','083122_record2','090122_record3','090222_record4'], #A16_5 excluded, A16_6 not collected 
             ['082322_record1','082422_record2','082522_record3','082622_record4','082722_record5','082822_record6'],
             ['082322_record1real','082422_record2','082522_record3','082622_record4','082722_record5','082822_record6'],
             ['102322_record1','102422_record2','102522_record3','102622_record4','102722_record5','102822_record6'],
             ['102322_record1','102422_record2','102522_record3','102622_record4','102722_record5','102822_record6'],
             ['102322_record1','102422_record2','102522_record3','102622_record4','102722_record5','102822_record6'],
             ['103122_record2','110122_record3','110222_record4','110322_record5rep','110422_record6','110522_record7'],
             ['110622_record1','110722_record2','110822_record3','110922_record4','111022_record5','111122_record6'],
             ['103022_record1','103122_record2','110122_record3','110222_record4','110322_record5','110422_record6'],
             ['103022_record1','103122_record2','110122_record3','110222_record4'], #MA7_5 excluded, 6 not collected
             ['111322_record1','111422_record2','111522_record3','111622_record4','111722_record5','111822_record6'],
             ['111322_record1','111422_record2','111522_record3','111622_record4','111722_record5','111822_record6'],
             ['111322_record1','111422_record2','111522_record3','111622_record4','111722_record5','111822_record6'], 
             ['092522_record1','092622_record2','092722_record3','092822_record4','092922_record5','093022_record6'],
             ['091822_record1','091922_record2','092022_record3','092122_record4','092222_record5','092322_record6'],
             ['092522_record1','092622_record2','092722_record3','092822_record4','092922_record5','093022_record6'],
             ['092522_record1','092622_record2','092722_record3','092822_record4','092922_record5','093022_record6'],
             ['091822_record1','091922_record2','092022_record3','092122_record4','092222_record5','092322_record6'], #end cohortc
             ['012723_record2','012823_record3','012923_record4','013023_record5','013123_record6','020123_record7'],
             ['012623_record1','012723_record2','012823_record3','012923_record4','013023_record5','013123_record6'],
             ['012923_record2','013023_record3','013123_record4','020123_record5','020223_record6','020323_record7'],
             ['020923_record1','021023_record2','021123_record3','021223_record4','021323_record5','021423_record6'],
             ['022623_record1','022723_record2','022823_record3','030123_record4','030223_record5','030323_record6'],
             ['021623_record1','021723_record2','021823_record3','021923_record4','022023_record5','022123_record6'],
             ['021623_record1','021723_record2','021823_record3','021923_record4','022023_record5','022123_record6'],
             ['021623_record1','021723_record2','021823_record3','021923_record4','022023_record5rep','022123_record6'],
             ['022623_record1','022723_record2','022823_record3','030123_record4','030223_record5','030323_record6'] #end cohort d 
            ]) #list of sessions
# Out:
# ['A3' 'A4' 'A5' 'A6' 'A7' 'Y2' 'Y3' 'Y4' 'A12' 'A13' 'Y11' 'Y16' 'Y17'
#  'Y18' 'Y19' 'Y9' 'A14' 'A15' 'A16' 'A17' 'A18' 'MA1F' 'MA2F' 'MA3M'
#  'MA4M' 'MA5M' 'MA6M' 'MA7M' 'MA8F' 'MA9F' 'MA10F' 'Y20' 'Y21' 'Y22' 'Y23'
#  'Y24' 'A19' 'A20' 'A22' 'A23' 'A24' 'Y25' 'Y26' 'Y27' 'Y28']

# %% [markdown]
# # Classify putative inhibitory interneurons based on waveforms.

# %% [markdown]
# First, in all sessions, you will identify putative inhibitory interneurons based on dual thresholds on FR and waveform duration.

# %%
''' Classify putative inhibitory interneurons & plot Extended Figure Data 6A'''

#load all neural data sessions
mice = all_mice
sessions = all_sessions

# Make a dict to hold data
data = {}

for session, m in zip(sessions, mice):
    data[m] = {}
    
    for s in session:
        data[m][s] = {}

folder = 'C:/Users/Python/Desktop/Dryad/waveform_metrics/' # adjust to location of downloaded metrics folders
save_folder = 'C:/Users/Python/Desktop/LocalData/intnspeedcells/' # adjust to save folder path
load_folder = 'C:/Users/Python/Desktop/LocalData/filtered/' # adjust to data folder
    
intperc = [] 

for m, session in zip(mice,sessions):
    
    seshcount = 1 
    
    for s in session:
        d = data[m][s]   
        rawdata_file = 'RAW_' + m + '_' + s + '.npy'
        raw = np.load(load_folder + rawdata_file, allow_pickle=True)
        cell_IDs = raw.item().get('cellsfil')
        
        # load waveform parameters of interest for good cells only, drop rows w/ NaN, standardize for kmeans clustering
        file_name = m + '_' + str(seshcount) + '_metrics.csv'
        metrics = pd.read_csv(folder + file_name)
        fullgcmetrics = metrics[metrics['cluster_id'].isin(list(cell_IDs))]
        gcmetrics = fullgcmetrics.dropna(subset = ['duration','PT_ratio'])
        
        duration = np.asarray(gcmetrics['duration'])
        PTR = np.asarray(gcmetrics['PT_ratio'])
        halfwidth = np.asarray(gcmetrics['halfwidth'])
        recslope = np.asarray(gcmetrics['recovery_slope'])
        firingrate = np.asarray(gcmetrics['firing_rate'])
        
        #examine duration threshold and plot
        idx = np.where((duration < 0.35) | (firingrate > 40))[0]
        print('Interneurons %: ' + str(len(idx)/len(cell_IDs)*100))
        oppidx = np.setdiff1d(np.arange(0,len(firingrate),1), idx)
        
        intperc = np.append(intperc, np.round(100*len(idx)/len(cell_IDs), 2))
        
        #Plot Extended Data Figure 6A:
        if (m == 'A12') and (s == '051922_record2'):
            fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (3.75,1.25))
            ax1.scatter(PTR[idx], duration[idx], color = 'blue', alpha = 1, s = 5, edgecolor = 'None')
            ax1.scatter(PTR[oppidx], duration[oppidx], color = 'green', alpha = 1, s = 5, edgecolor = 'None')
            ax1.set_xlabel('Peak:Trough', fontsize = 9)
            ax1.set_ylabel('Duration (ms)', fontsize = 9)
            ax1.hlines(0.35,0,1.25, colors = 'k', linestyles = '--', linewidth = 0.75)
            ax1.set_xlim([0,1.25])
            ax1.set_xticks([0,0.5,1])
            ax1.tick_params(labelsize = 8)

            #plot histograms of widths w/ cluster labels applied
            ax2.hist(halfwidth[idx], color = 'blue', histtype = 'step')
            ax2.hist(halfwidth[oppidx], color = 'green', histtype = 'step')
            ax2.set_xlabel('Width (ms)', fontsize = 9)
            ax2.set_ylabel('Cells', fontsize = 9)
            ax2.tick_params(labelsize = 8)

            #plot histograms of widths w/ cluster labels applied
            ax3.hist(firingrate[idx], color = 'blue', histtype = 'step')
            ax3.hist(firingrate[oppidx], color = 'green', histtype = 'step')
            ax3.set_xlabel('FR (Hz)', fontsize = 9)
            ax3.tick_params(labelsize = 8)
            ax3.set_ylim(ax2.get_ylim())

            fig.suptitle(m + '_' + s[-1:] + ', IN %: ' + str(np.round(100*len(idx)/len(cell_IDs) , 2)), fontsize = 10)
            plt.subplots_adjust(top = 0.8)
            #plt.savefig(save_folder + m + '_' + s + '_' + 'qualityint.png', dpi=400, bbox_inches='tight')
            #plt.savefig(save_folder + m + '_' + s + '_' + 'qualityint.svg', dpi=400, bbox_inches='tight')
            plt.show()

        seshcount += 1
        
        #create boolean (0 = excitatory cell; 1 = interneuron)
        intn = np.zeros(len(cell_IDs))
        intn[idx] = 1
        intn[oppidx] = 0
          
        #save the boolean interneuron classifcation    
        intn_file = 'intn_' + m + '_' + s + '.npy'
        #np.save(save_folder + intn_file, intn)
        print('saved interneuron classification as npy file for mouse ' + m + ' session '+ s)

print('Mean, SEM % interneurons / session:')
print(np.mean(intperc), stats.sem(intperc))
# Out:
# Interneurons %: 22.932330827067666
# saved interneuron classification as npy file for mouse A3 session 0122_record1
# Interneurons %: 36.27450980392157
# saved interneuron classification as npy file for mouse A3 session 0123_record2
# Interneurons %: 17.874396135265698
# saved interneuron classification as npy file for mouse A3 session 0124_record3
# Interneurons %: 21.070234113712374
# saved interneuron classification as npy file for mouse A3 session 0125_record4
# Interneurons %: 19.51219512195122
# saved interneuron classification as npy file for mouse A3 session 0126_record5
# Interneurons %: 21.052631578947366
# saved interneuron classification as npy file for mouse A3 session 0127_record6
# Interneurons %: 20.88888888888889
# saved interneuron classification as npy file for mouse A4 session 0122_record1
# Interneurons %: 26.063829787234045
# saved interneuron classification as npy file for mouse A4 session 0123_record2
# Interneurons %: 29.133858267716533
# saved interneuron classification as npy file for mouse A4 session 0124_record3
# Interneurons %: 25.86750788643533
# saved interneuron classification as npy file for mouse A4 session 0125_record4
# Interneurons %: 26.409495548961427
# saved interneuron classification as npy file for mouse A4 session 0126_record5
# Interneurons %: 21.73913043478261
# saved interneuron classification as npy file for mouse A4 session 0127_record6
# Interneurons %: 31.84713375796178
# saved interneuron classification as npy file for mouse A5 session 0401_record1
# Interneurons %: 25.0
# saved interneuron classification as npy file for mouse A5 session 0401_record2b
# Interneurons %: 25.324675324675322
# saved interneuron classification as npy file for mouse A5 session 0403_record3
# Interneurons %: 25.806451612903224
# saved interneuron classification as npy file for mouse A5 session 0404_record4
# Interneurons %: 33.54430379746836
# saved interneuron classification as npy file for mouse A5 session 0405_record5
# Interneurons %: 29.069767441860467
# saved interneuron classification as npy file for mouse A5 session 0406_record6
# Interneurons %: 29.268292682926827
# saved interneuron classification as npy file for mouse A6 session 0401_record1
# Interneurons %: 41.41414141414141
# saved interneuron classification as npy file for mouse A6 session 0402_record2
# Interneurons %: 25.0
# saved interneuron classification as npy file for mouse A6 session 0403_record3
# Interneurons %: 25.213675213675213
# saved interneuron classification as npy file for mouse A6 session 0404_record4
# Interneurons %: 23.78048780487805
# saved interneuron classification as npy file for mouse A6 session 0405_record5
# Interneurons %: 32.87671232876712
# saved interneuron classification as npy file for mouse A6 session 0406_record6
# Interneurons %: 20.13888888888889
# saved interneuron classification as npy file for mouse A7 session 0414_record1
# Interneurons %: 7.920792079207921
# saved interneuron classification as npy file for mouse A7 session 0415_record2
# Interneurons %: 11.538461538461538
# saved interneuron classification as npy file for mouse A7 session 0416_record3
# Interneurons %: 28.98172323759791
# saved interneuron classification as npy file for mouse A7 session 0417_record4
# Interneurons %: 23.137254901960784
# saved interneuron classification as npy file for mouse A7 session 0418_record5
# Interneurons %: 6.8493150684931505
# saved interneuron classification as npy file for mouse A7 session 0419_record6
# Interneurons %: 18.954248366013072
# saved interneuron classification as npy file for mouse Y2 session 1024_record1
# Interneurons %: 28.57142857142857
# saved interneuron classification as npy file for mouse Y2 session 1025_record2
# Interneurons %: 23.364485981308412
# saved interneuron classification as npy file for mouse Y2 session 1026_record3
# Interneurons %: 66.11111111111111
# saved interneuron classification as npy file for mouse Y2 session 1027_record4
# Interneurons %: 58.06451612903226
# saved interneuron classification as npy file for mouse Y2 session 1028_record5_2
# Interneurons %: 35.146443514644346
# saved interneuron classification as npy file for mouse Y3 session 1016_record1
# Interneurons %: 19.35483870967742
# saved interneuron classification as npy file for mouse Y3 session 1019_record3
# Interneurons %: 29.347826086956523
# saved interneuron classification as npy file for mouse Y3 session 1020_record4
# Interneurons %: 23.52941176470588
# saved interneuron classification as npy file for mouse Y3 session 1021_record5
# Interneurons %: 21.011673151750973
# saved interneuron classification as npy file for mouse Y3 session 1022_record6
# Interneurons %: 20.57142857142857
# saved interneuron classification as npy file for mouse Y4 session 1114_record1
# Interneurons %: 44.09448818897638
# saved interneuron classification as npy file for mouse Y4 session 1115_record2
# Interneurons %: 27.77777777777778
# saved interneuron classification as npy file for mouse Y4 session 1116_record3
# Interneurons %: 15.584415584415584
# saved interneuron classification as npy file for mouse Y4 session 1117_record4
# Interneurons %: 10.945273631840797
# saved interneuron classification as npy file for mouse Y4 session 1118_record5
# Interneurons %: 15.151515151515152
# saved interneuron classification as npy file for mouse Y4 session 1119_record6
# Interneurons %: 22.07207207207207
# saved interneuron classification as npy file for mouse A12 session 051822_record1
# Interneurons %: 23.497267759562842
# saved interneuron classification as npy file for mouse A12 session 051922_record2
# Interneurons %: 15.695067264573993
# saved interneuron classification as npy file for mouse A12 session 052022_record3
# Interneurons %: 43.12169312169312
# saved interneuron classification as npy file for mouse A12 session 052122_record4
# Interneurons %: 15.816326530612246
# saved interneuron classification as npy file for mouse A12 session 052222_record5
# Interneurons %: 34.78260869565217
# saved interneuron classification as npy file for mouse A12 session 052322_record6
# Interneurons %: 28.38283828382838
# saved interneuron classification as npy file for mouse A13 session 050522_record1
# Interneurons %: 21.843971631205676
# saved interneuron classification as npy file for mouse A13 session 050622_record2
# Interneurons %: 13.428571428571429
# saved interneuron classification as npy file for mouse A13 session 050722_record3
# Interneurons %: 23.78640776699029
# saved interneuron classification as npy file for mouse A13 session 050822_record4
# Interneurons %: 32.367149758454104
# saved interneuron classification as npy file for mouse A13 session 050922_record5
# Interneurons %: 23.154362416107382
# saved interneuron classification as npy file for mouse A13 session 051022_record6
# Interneurons %: 30.47945205479452
# saved interneuron classification as npy file for mouse Y11 session 050522_record1
# Interneurons %: 31.08108108108108
# saved interneuron classification as npy file for mouse Y11 session 050622_record2
# Interneurons %: 16.933638443935926
# saved interneuron classification as npy file for mouse Y11 session 050722_record3
# Interneurons %: 20.711974110032365
# saved interneuron classification as npy file for mouse Y11 session 050822_record4
# Interneurons %: 21.763085399449036
# saved interneuron classification as npy file for mouse Y11 session 051022_record6
# Interneurons %: 24.264705882352942
# saved interneuron classification as npy file for mouse Y16 session 062222_record3
# Interneurons %: 28.444444444444443
# saved interneuron classification as npy file for mouse Y16 session 062322_record4
# Interneurons %: 0.0
# saved interneuron classification as npy file for mouse Y16 session 062522_record5
# Interneurons %: 8.275862068965518
# saved interneuron classification as npy file for mouse Y17 session 062822_record1
# Interneurons %: 20.903954802259886
# saved interneuron classification as npy file for mouse Y17 session 062922_record2
# Interneurons %: 18.88888888888889
# saved interneuron classification as npy file for mouse Y17 session 063022_record3
# Interneurons %: 18.23204419889503
# saved interneuron classification as npy file for mouse Y17 session 070122_record4
# Interneurons %: 20.87227414330218
# saved interneuron classification as npy file for mouse Y17 session 070222_record5
# Interneurons %: 12.88888888888889
# saved interneuron classification as npy file for mouse Y17 session 070322_record6
# Interneurons %: 14.550264550264549
# saved interneuron classification as npy file for mouse Y18 session 062022_record1
# Interneurons %: 15.19434628975265
# saved interneuron classification as npy file for mouse Y18 session 062122_record2
# Interneurons %: 19.047619047619047
# saved interneuron classification as npy file for mouse Y18 session 062222_record3
# Interneurons %: 22.493887530562347
# saved interneuron classification as npy file for mouse Y18 session 062322_record4
# Interneurons %: 15.406162464985995
# saved interneuron classification as npy file for mouse Y18 session 062522_record5
# Interneurons %: 18.095238095238095
# saved interneuron classification as npy file for mouse Y18 session 062622_record6
# Interneurons %: 19.10569105691057
# saved interneuron classification as npy file for mouse Y19 session 062822_record1
# Interneurons %: 16.793893129770993
# saved interneuron classification as npy file for mouse Y19 session 062922_record2
# Interneurons %: 16.8
# saved interneuron classification as npy file for mouse Y19 session 063022_record3
# Interneurons %: 13.513513513513514
# saved interneuron classification as npy file for mouse Y19 session 070122_record4
# Interneurons %: 16.867469879518072
# saved interneuron classification as npy file for mouse Y19 session 070222_record5
# Interneurons %: 13.059701492537313
# saved interneuron classification as npy file for mouse Y19 session 070322_record6
# Interneurons %: 19.900497512437813
# saved interneuron classification as npy file for mouse Y9 session 051922_record2
# Interneurons %: 11.926605504587156
# saved interneuron classification as npy file for mouse Y9 session 052022_record3
# Interneurons %: 21.296296296296298
# saved interneuron classification as npy file for mouse A14 session 083022_record1
# Interneurons %: 24.124513618677042
# saved interneuron classification as npy file for mouse A14 session 083122_record2
# Interneurons %: 33.33333333333333
# saved interneuron classification as npy file for mouse A14 session 090122_record3
# Interneurons %: 58.18181818181818
# saved interneuron classification as npy file for mouse A15 session 083022_record1
# Interneurons %: 23.943661971830984
# saved interneuron classification as npy file for mouse A15 session 083122_record2
# Interneurons %: 21.0
# saved interneuron classification as npy file for mouse A15 session 090122_record3
# Interneurons %: 21.649484536082475
# saved interneuron classification as npy file for mouse A15 session 090222_record4
# Interneurons %: 28.834355828220858
# saved interneuron classification as npy file for mouse A15 session 090322_record5
# Interneurons %: 32.16374269005848
# saved interneuron classification as npy file for mouse A15 session 090422_record6
# Interneurons %: 32.30769230769231
# saved interneuron classification as npy file for mouse A16 session 083022_record1
# Interneurons %: 31.794871794871792
# saved interneuron classification as npy file for mouse A16 session 083122_record2
# Interneurons %: 56.75675675675676
# saved interneuron classification as npy file for mouse A16 session 090122_record3
# Interneurons %: 22.3463687150838
# saved interneuron classification as npy file for mouse A16 session 090222_record4
# Interneurons %: 30.05464480874317
# saved interneuron classification as npy file for mouse A17 session 082322_record1
# Interneurons %: 50.0
# saved interneuron classification as npy file for mouse A17 session 082422_record2
# Interneurons %: 20.444444444444446
# saved interneuron classification as npy file for mouse A17 session 082522_record3
# Interneurons %: 25.153374233128833
# saved interneuron classification as npy file for mouse A17 session 082622_record4
# Interneurons %: 18.498659517426276
# saved interneuron classification as npy file for mouse A17 session 082722_record5
# Interneurons %: 18.478260869565215
# saved interneuron classification as npy file for mouse A17 session 082822_record6
# Interneurons %: 20.0
# saved interneuron classification as npy file for mouse A18 session 082322_record1real
# Interneurons %: 18.773234200743495
# saved interneuron classification as npy file for mouse A18 session 082422_record2
# Interneurons %: 19.565217391304348
# saved interneuron classification as npy file for mouse A18 session 082522_record3
# Interneurons %: 21.263482280431433
# saved interneuron classification as npy file for mouse A18 session 082622_record4
# Interneurons %: 25.11013215859031
# saved interneuron classification as npy file for mouse A18 session 082722_record5
# Interneurons %: 22.267206477732792
# saved interneuron classification as npy file for mouse A18 session 082822_record6
# Interneurons %: 22.93577981651376
# saved interneuron classification as npy file for mouse MA1F session 102322_record1
# Interneurons %: 26.82926829268293
# saved interneuron classification as npy file for mouse MA1F session 102422_record2
# Interneurons %: 24.47761194029851
# saved interneuron classification as npy file for mouse MA1F session 102522_record3
# Interneurons %: 28.947368421052634
# saved interneuron classification as npy file for mouse MA1F session 102622_record4
# Interneurons %: 19.92753623188406
# saved interneuron classification as npy file for mouse MA1F session 102722_record5
# Interneurons %: 20.54794520547945
# saved interneuron classification as npy file for mouse MA1F session 102822_record6
# Interneurons %: 24.1635687732342
# saved interneuron classification as npy file for mouse MA2F session 102322_record1
# Interneurons %: 17.72151898734177
# saved interneuron classification as npy file for mouse MA2F session 102422_record2
# Interneurons %: 23.11320754716981
# saved interneuron classification as npy file for mouse MA2F session 102522_record3
# Interneurons %: 16.728624535315987
# saved interneuron classification as npy file for mouse MA2F session 102622_record4
# Interneurons %: 23.404255319148938
# saved interneuron classification as npy file for mouse MA2F session 102722_record5
# Interneurons %: 23.367697594501717
# saved interneuron classification as npy file for mouse MA2F session 102822_record6
# Interneurons %: 38.144329896907216
# saved interneuron classification as npy file for mouse MA3M session 102322_record1
# Interneurons %: 33.33333333333333
# saved interneuron classification as npy file for mouse MA3M session 102422_record2
# Interneurons %: 31.693989071038253
# saved interneuron classification as npy file for mouse MA3M session 102522_record3
# Interneurons %: 21.910112359550563
# saved interneuron classification as npy file for mouse MA3M session 102622_record4
# Interneurons %: 26.190476190476193
# saved interneuron classification as npy file for mouse MA3M session 102722_record5
# Interneurons %: 25.263157894736842
# saved interneuron classification as npy file for mouse MA3M session 102822_record6
# Interneurons %: 36.3265306122449
# saved interneuron classification as npy file for mouse MA4M session 103122_record2
# Interneurons %: 37.878787878787875
# saved interneuron classification as npy file for mouse MA4M session 110122_record3
# Interneurons %: 34.24657534246575
# saved interneuron classification as npy file for mouse MA4M session 110222_record4
# Interneurons %: 25.36231884057971
# saved interneuron classification as npy file for mouse MA4M session 110322_record5rep
# Interneurons %: 27.859237536656888
# saved interneuron classification as npy file for mouse MA4M session 110422_record6
# Interneurons %: 26.38888888888889
# saved interneuron classification as npy file for mouse MA4M session 110522_record7
# Interneurons %: 31.05590062111801
# saved interneuron classification as npy file for mouse MA5M session 110622_record1
# Interneurons %: 31.52804642166344
# saved interneuron classification as npy file for mouse MA5M session 110722_record2
# Interneurons %: 27.30627306273063
# saved interneuron classification as npy file for mouse MA5M session 110822_record3
# Interneurons %: 29.268292682926827
# saved interneuron classification as npy file for mouse MA5M session 110922_record4
# Interneurons %: 21.875
# saved interneuron classification as npy file for mouse MA5M session 111022_record5
# Interneurons %: 22.5
# saved interneuron classification as npy file for mouse MA5M session 111122_record6
# Interneurons %: 24.458204334365323
# saved interneuron classification as npy file for mouse MA6M session 103022_record1
# Interneurons %: 32.720588235294116
# saved interneuron classification as npy file for mouse MA6M session 103122_record2
# Interneurons %: 25.958702064896755
# saved interneuron classification as npy file for mouse MA6M session 110122_record3
# Interneurons %: 22.5
# saved interneuron classification as npy file for mouse MA6M session 110222_record4
# Interneurons %: 43.28358208955223
# saved interneuron classification as npy file for mouse MA6M session 110322_record5
# Interneurons %: 22.839506172839506
# saved interneuron classification as npy file for mouse MA6M session 110422_record6
# Interneurons %: 31.41592920353982
# saved interneuron classification as npy file for mouse MA7M session 103022_record1
# Interneurons %: 31.716417910447763
# saved interneuron classification as npy file for mouse MA7M session 103122_record2
# Interneurons %: 37.254901960784316
# saved interneuron classification as npy file for mouse MA7M session 110122_record3
# Interneurons %: 39.0625
# saved interneuron classification as npy file for mouse MA7M session 110222_record4
# Interneurons %: 28.09917355371901
# saved interneuron classification as npy file for mouse MA8F session 111322_record1
# Interneurons %: 17.888563049853374
# saved interneuron classification as npy file for mouse MA8F session 111422_record2
# Interneurons %: 17.218543046357617
# saved interneuron classification as npy file for mouse MA8F session 111522_record3
# Interneurons %: 20.23121387283237
# saved interneuron classification as npy file for mouse MA8F session 111622_record4
# Interneurons %: 25.327510917030565
# saved interneuron classification as npy file for mouse MA8F session 111722_record5
# Interneurons %: 38.1294964028777
# saved interneuron classification as npy file for mouse MA8F session 111822_record6
# Interneurons %: 25.557809330628807
# saved interneuron classification as npy file for mouse MA9F session 111322_record1
# Interneurons %: 21.649484536082475
# saved interneuron classification as npy file for mouse MA9F session 111422_record2
# Interneurons %: 18.95551257253385
# saved interneuron classification as npy file for mouse MA9F session 111522_record3
# Interneurons %: 28.205128205128204
# saved interneuron classification as npy file for mouse MA9F session 111622_record4
# Interneurons %: 32.70676691729324
# saved interneuron classification as npy file for mouse MA9F session 111722_record5
# Interneurons %: 26.08695652173913
# saved interneuron classification as npy file for mouse MA9F session 111822_record6
# Interneurons %: 22.084805653710244
# saved interneuron classification as npy file for mouse MA10F session 111322_record1
# Interneurons %: 31.117021276595747
# saved interneuron classification as npy file for mouse MA10F session 111422_record2
# Interneurons %: 33.746130030959755
# saved interneuron classification as npy file for mouse MA10F session 111522_record3
# Interneurons %: 32.06751054852321
# saved interneuron classification as npy file for mouse MA10F session 111622_record4
# Interneurons %: 29.447852760736197
# saved interneuron classification as npy file for mouse MA10F session 111722_record5
# Interneurons %: 26.23318385650224
# saved interneuron classification as npy file for mouse MA10F session 111822_record6
# Interneurons %: 26.27118644067797
# saved interneuron classification as npy file for mouse Y20 session 092522_record1
# Interneurons %: 12.666666666666668
# saved interneuron classification as npy file for mouse Y20 session 092622_record2
# Interneurons %: 28.64864864864865
# saved interneuron classification as npy file for mouse Y20 session 092722_record3
# Interneurons %: 13.20754716981132
# saved interneuron classification as npy file for mouse Y20 session 092822_record4
# Interneurons %: 21.153846153846153
# saved interneuron classification as npy file for mouse Y20 session 092922_record5
# Interneurons %: 14.11042944785276
# saved interneuron classification as npy file for mouse Y20 session 093022_record6
# Interneurons %: 21.844660194174757
# saved interneuron classification as npy file for mouse Y21 session 091822_record1
# Interneurons %: 16.071428571428573
# saved interneuron classification as npy file for mouse Y21 session 091922_record2
# Interneurons %: 21.846153846153847
# saved interneuron classification as npy file for mouse Y21 session 092022_record3
# Interneurons %: 27.251184834123222
# saved interneuron classification as npy file for mouse Y21 session 092122_record4
# Interneurons %: 24.514563106796118
# saved interneuron classification as npy file for mouse Y21 session 092222_record5
# Interneurons %: 31.08108108108108
# saved interneuron classification as npy file for mouse Y21 session 092322_record6
# Interneurons %: 19.45288753799392
# saved interneuron classification as npy file for mouse Y22 session 092522_record1
# Interneurons %: 18.415841584158414
# saved interneuron classification as npy file for mouse Y22 session 092622_record2
# Interneurons %: 17.26027397260274
# saved interneuron classification as npy file for mouse Y22 session 092722_record3
# Interneurons %: 31.46067415730337
# saved interneuron classification as npy file for mouse Y22 session 092822_record4
# Interneurons %: 18.91891891891892
# saved interneuron classification as npy file for mouse Y22 session 092922_record5
# Interneurons %: 17.209302325581397
# saved interneuron classification as npy file for mouse Y22 session 093022_record6
# Interneurons %: 19.733333333333334
# saved interneuron classification as npy file for mouse Y23 session 092522_record1
# Interneurons %: 23.450586264656618
# saved interneuron classification as npy file for mouse Y23 session 092622_record2
# Interneurons %: 17.687074829931973
# saved interneuron classification as npy file for mouse Y23 session 092722_record3
# Interneurons %: 29.75206611570248
# saved interneuron classification as npy file for mouse Y23 session 092822_record4
# Interneurons %: 20.652173913043477
# saved interneuron classification as npy file for mouse Y23 session 092922_record5
# Interneurons %: 15.451895043731778
# saved interneuron classification as npy file for mouse Y23 session 093022_record6
# Interneurons %: 9.329446064139942
# saved interneuron classification as npy file for mouse Y24 session 091822_record1
# Interneurons %: 15.568862275449103
# saved interneuron classification as npy file for mouse Y24 session 091922_record2
# Interneurons %: 13.62530413625304
# saved interneuron classification as npy file for mouse Y24 session 092022_record3
# Interneurons %: 12.854030501089325
# saved interneuron classification as npy file for mouse Y24 session 092122_record4
# Interneurons %: 13.492063492063492
# saved interneuron classification as npy file for mouse Y24 session 092222_record5
# Interneurons %: 11.347517730496454
# saved interneuron classification as npy file for mouse Y24 session 092322_record6
# Interneurons %: 32.77591973244147
# saved interneuron classification as npy file for mouse A19 session 012723_record2
# Interneurons %: 31.547619047619047
# saved interneuron classification as npy file for mouse A19 session 012823_record3
# Interneurons %: 25.49019607843137
# saved interneuron classification as npy file for mouse A19 session 012923_record4
# Interneurons %: 25.0
# saved interneuron classification as npy file for mouse A19 session 013023_record5
# Interneurons %: 25.906735751295333
# saved interneuron classification as npy file for mouse A19 session 013123_record6
# Interneurons %: 24.390243902439025
# saved interneuron classification as npy file for mouse A19 session 020123_record7
# Interneurons %: 31.818181818181817
# saved interneuron classification as npy file for mouse A20 session 012623_record1
# Interneurons %: 29.468599033816425
# saved interneuron classification as npy file for mouse A20 session 012723_record2
# Interneurons %: 23.544303797468356
# saved interneuron classification as npy file for mouse A20 session 012823_record3
# Interneurons %: 26.785714285714285
# saved interneuron classification as npy file for mouse A20 session 012923_record4
# Interneurons %: 30.737704918032787
# saved interneuron classification as npy file for mouse A20 session 013023_record5
# Interneurons %: 47.20812182741117
# saved interneuron classification as npy file for mouse A20 session 013123_record6
# Interneurons %: 22.3463687150838
# saved interneuron classification as npy file for mouse A22 session 012923_record2
# Interneurons %: 16.434540389972145
# saved interneuron classification as npy file for mouse A22 session 013023_record3
# Interneurons %: 18.660287081339714
# saved interneuron classification as npy file for mouse A22 session 013123_record4
# Interneurons %: 29.310344827586203
# saved interneuron classification as npy file for mouse A22 session 020123_record5
# Interneurons %: 28.14070351758794
# saved interneuron classification as npy file for mouse A22 session 020223_record6
# Interneurons %: 29.767441860465116
# saved interneuron classification as npy file for mouse A22 session 020323_record7
# Interneurons %: 31.70731707317073
# saved interneuron classification as npy file for mouse A23 session 020923_record1
# Interneurons %: 36.11111111111111
# saved interneuron classification as npy file for mouse A23 session 021023_record2
# Interneurons %: 23.870967741935484
# saved interneuron classification as npy file for mouse A23 session 021123_record3
# Interneurons %: 38.19444444444444
# saved interneuron classification as npy file for mouse A23 session 021223_record4
# Interneurons %: 16.666666666666664
# saved interneuron classification as npy file for mouse A23 session 021323_record5
# Interneurons %: 20.614035087719298
# saved interneuron classification as npy file for mouse A23 session 021423_record6
# Interneurons %: 33.793103448275865
# saved interneuron classification as npy file for mouse A24 session 022623_record1
# Interneurons %: 24.361948955916475
# saved interneuron classification as npy file for mouse A24 session 022723_record2
# Interneurons %: 25.981873111782477
# saved interneuron classification as npy file for mouse A24 session 022823_record3
# Interneurons %: 24.890829694323145
# saved interneuron classification as npy file for mouse A24 session 030123_record4
# Interneurons %: 17.877094972067038
# saved interneuron classification as npy file for mouse A24 session 030223_record5
# Interneurons %: 21.176470588235293
# saved interneuron classification as npy file for mouse A24 session 030323_record6
# Interneurons %: 25.0
# saved interneuron classification as npy file for mouse Y25 session 021623_record1
# Interneurons %: 20.170454545454543
# saved interneuron classification as npy file for mouse Y25 session 021723_record2
# Interneurons %: 28.78787878787879
# saved interneuron classification as npy file for mouse Y25 session 021823_record3
# Interneurons %: 26.440677966101696
# saved interneuron classification as npy file for mouse Y25 session 021923_record4
# Interneurons %: 25.7396449704142
# saved interneuron classification as npy file for mouse Y25 session 022023_record5
# Interneurons %: 24.65753424657534
# saved interneuron classification as npy file for mouse Y25 session 022123_record6
# Interneurons %: 15.481171548117153
# saved interneuron classification as npy file for mouse Y26 session 021623_record1
# Interneurons %: 14.634146341463413
# saved interneuron classification as npy file for mouse Y26 session 021723_record2
# Interneurons %: 19.428571428571427
# saved interneuron classification as npy file for mouse Y26 session 021823_record3
# Interneurons %: 5.0
# saved interneuron classification as npy file for mouse Y26 session 021923_record4
# Interneurons %: 13.872832369942195
# saved interneuron classification as npy file for mouse Y26 session 022023_record5
# Interneurons %: 27.184466019417474
# saved interneuron classification as npy file for mouse Y26 session 022123_record6
# Interneurons %: 15.0
# saved interneuron classification as npy file for mouse Y27 session 021623_record1
# Interneurons %: 22.459893048128343
# saved interneuron classification as npy file for mouse Y27 session 021723_record2
# Interneurons %: 18.93491124260355
# saved interneuron classification as npy file for mouse Y27 session 021823_record3
# Interneurons %: 17.307692307692307
# saved interneuron classification as npy file for mouse Y27 session 021923_record4
# Interneurons %: 19.607843137254903
# saved interneuron classification as npy file for mouse Y27 session 022023_record5rep
# Interneurons %: 28.57142857142857
# saved interneuron classification as npy file for mouse Y27 session 022123_record6
# Interneurons %: 37.77777777777778
# saved interneuron classification as npy file for mouse Y28 session 022623_record1
# Interneurons %: 22.01086956521739
# saved interneuron classification as npy file for mouse Y28 session 022723_record2
# Interneurons %: 26.605504587155966
# saved interneuron classification as npy file for mouse Y28 session 022823_record3
# Interneurons %: 28.26086956521739
# saved interneuron classification as npy file for mouse Y28 session 030123_record4
# Interneurons %: 21.96652719665272
# saved interneuron classification as npy file for mouse Y28 session 030223_record5
# Interneurons %: 26.139088729016784
# saved interneuron classification as npy file for mouse Y28 session 030323_record6
# Mean, SEM % interneurons / session:
# 24.549683794466404 0.5465142433290131

# %% [markdown]
# # Run shuffle & calculate scores for each rep for RF sessions

# %% [markdown]
# In Random Foraging (RF) sessions, we will now classify speed-tuned cells and spatial cells. In half of the RF sessions (male mice), dark trial data is available to differentiate grid and non-grid spatial cells. In those sessions, we will also calculate the height of the shuffle's dark FR autocorrelation at the same lag as the largest peak in the real dark FR autocorrelation.

# %%
''' Load in the RF sessions only & reset dictionary'''
# Define mice, sessions for particular cohorts
mice , mice_ind, _  = np.intersect1d(all_mice,(np.union1d(cohorta_mice, cohortb_mice)), return_indices = True) # RF mice
#mice , mice_ind, _  = np.intersect1d(all_mice,np.union1d(cohortc_mice, cohortd_mice), return_indices = True) # SM mice

# If you found the intersection 
sessions = []
for i in mice_ind:
    sessions.append(all_sessions[i])

# Make a dict to hold data
data = {}

for session, m in zip(sessions, mice):
    data[m] = {}
    
    for s in session:
        data[m][s] = {}

# %%
''' Calculate 100x Shuffled Scores for each Cell in all RF Sessions 

Shuffle speed & speed stability scores are used to classify speed-tuning. 
Shuffle spatial sparsity & coherence scores are used to classify position-tuning, identifying spatial cells.
Shuffle dark FR autocorrelation max peak height at the same lag as the actual dark max peak is used to differentiate
grid from non-grid spatial cells in the mice with dark trials (Cohort B).

Expected run time is hours per session.

'''
n_rep = 100 # number of shuffles
sigma = 20  # smoothing factor for speed & speed stability scores
n_bin = 8 #n position bins considered for speed stability score
track_length = 400 #cm
bins = np.arange(0,track_length + (track_length/n_bin),(track_length/n_bin))
n_dark = 20 #trials
lags = np.arange(0,801,1)

save_folder = 'C:/Users/Python/Desktop/LocalData/shuffscores/' #adjust path 
dataload_folder = 'C:/Users/Python/Desktop/LocalData/filtered/'#adjust path to output of Import & Filter notebook

for m, session in zip(mice,sessions):
    for s in tdqm(session):
        d = data[m][s]
        
        #load in data
        rawdata_file = 'RAW_' + m + '_' + s + '.npy'
        behavior_file = 'BEHAVIOR_' + m + '_' + s + '.npy'
        
        raw = np.load(dataload_folder + rawdata_file, allow_pickle=True)
        behaviorfil = np.load(dataload_folder + behavior_file, allow_pickle=False)
        
        rawspeed = raw.item().get('speed')
        speed = behaviorfil[:,1]
        
        sp = raw.item().get('sp')
        spiket = sp['st'].copy()
        cluster_id = sp['clu'].copy()
        cell_IDs = raw.item().get('cellsfil')
        posx = raw.item().get('posx')
        post = raw.item().get('post')
        
        dt = np.unique(np.round(np.diff(post),4))
        if len(dt) > 1: # discard duplicate frame entries if they occurred
            dt = dt[dt != 0]
            dt_to_trash = np.where(np.diff(post) == 0)[0]
        else:
            dt_to_trash = [] 
            
        posxfil = behaviorfil[:,0]
        trial = behaviorfil[:,2]
        trials = np.unique(trial)
        postfil = behaviorfil[:,3]
        
        # filter spikes & position frames by speed < 2cm/s or out of track limits 
        speed_to_trash = find(rawspeed < 2)
        pos_to_trash = find((posx < 0) | (posx > 400))
        trash_idx = np.unique(np.concatenate((dt_to_trash, speed_to_trash, pos_to_trash)))
        keep_idx = np.setdiff1d(np.arange(len(rawspeed)), trash_idx)
        
        # find indices of spike corresponding to 8 x 50cm bins along the track based on filtered position
        bin_idx = []
        for i in range(n_bin):
            if i == (n_bin - 1):
                idx = np.where((posxfil >= bins[i]) & (posxfil <= bins[i + 1]))[0]
            else:
                idx = np.where((posxfil >= bins[i]) & (posxfil < bins[i + 1]))[0]
            bin_idx.append(idx)
            
        if m in cohortb_mice:
            spikes_file = 'SPIKES_' + m + '_' + s +'.npy'
            Y = np.load(dataload_folder + spikes_file, allow_pickle=False) #pre-filtered for speeds >2cm/s, position-corrected spikes
            
            #get dark-only, normalized, smoothed spatial map & reshape into continuous vector for each cell
            FR, _ , _ = ps.tuning_curve_bytrial(posxfil, trial, Y, dt, b = 2, smooth=True, normalize=True, occupancy=True)
            stop_idx = np.where(trials == n_dark)[0][0]
            FR = FR[:stop_idx,:,:]
            n_trials = FR.shape[0]
            n_pos = FR.shape[1]
            n_cells = FR.shape[2]
            FR = (np.reshape(FR, (n_trials*n_pos, n_cells))).T

            #find max autocorrelation peaks for all cells; store height & prom of most prominent peak
            peak = [] # boolean if peak found
            maxpeak_locs = [] #stored lag of max peak if peak exist
            maxpeak_heights = [] # stored height of max peak, otherwise 0 if not exist
            maxpeak_proms = [] # stored prominence of max peak, otherwise 0 if not exist
            for i, c in enumerate(cell_IDs):
                sdx = np.where(cell_IDs == c)[0][0]
                autocorrelation = autocorr(FR[sdx,:],lags)
                normauto = autocorrelation / autocorrelation[0]
                peaks, properties = find_peaks(normauto, width = 10, height = 0.10, prominence = 0.15)
                proms = properties["prominences"]
                heights = properties["peak_heights"]

                if peaks.size > 0:
                    peak = np.append(peak,1)
                    maxpeak_locs = np.append(maxpeak_locs, peaks[np.argmax(proms)])
                    maxpeak_heights = np.append(maxpeak_heights, heights[np.argmax(proms)])
                    maxpeak_proms = np.append(maxpeak_proms, proms[np.argmax(proms)])
                else:
                    peak = np.append(peak,0)
                    maxpeak_heights = np.append(maxpeak_heights,0)
                    maxpeak_proms = np.append(maxpeak_proms,0)

            peak = peak.astype(bool)
            
            shuffmaxpeak_heights = np.zeros((n_rep, len(cell_IDs[peak])))
            
        #calculate & save shuffled speed scores
        shuffspeedscore = np.zeros((n_rep, len(cell_IDs)))
        shuffspeedstabscore = np.zeros((n_rep, len(cell_IDs)))
        shuffspatialcoherencescores = np.zeros((n_rep,len(cell_IDs)))
        shuffsparsityscores = np.zeros((n_rep,len(cell_IDs)))
        
        for n in tdqm(range(0, n_rep)):
            
            shuffspeed_score = []
            shuffspeedstab_score = []
            shuffspatialsparseness = []
            shuffspatialcoherence = []
            shuffheights = []
            
            B = np.zeros((len(rawspeed), len(cell_IDs))) # set empty shuffled FR matrix shape n_obs, n_cells
            for i, c in enumerate(cell_IDs):
                sdx = (np.where(cell_IDs==c)[0][0]).astype(int)
                
                #get actual spike times for each cell
                st = spiket[cluster_id == c]
                st = st[(st >= min(post)) & (st <= max(post))]

                #get shuffle times
                st_shuf = st - min(post)
                total_time = max(post) - min(post)
                add = np.random.uniform(0.02,total_time,1)
                st_shuf = (st_shuf + add) % total_time
                st_shuf = st_shuf + min(post)
                                                        
                #get unfiltered spike train
                spike_ct = np.zeros_like(post)
                spike_idx = np.digitize(st_shuf,post) #obs corresponding to where each shuffled spike occurs

                idx, cts = np.unique(spike_idx, return_counts = True)
                spike_ct[idx] = cts
                B[:,i] = spike_ct

                #check for & interpolate any missing values; smooth if necessary
                if sum(np.isnan(B[:,i])) > 0:
                    B[:,i] = get.nan_interp(B[:,i])  

            #apply filter spike train by speed & posx errors
            B = B[keep_idx,:]
            total_time = max(postfil) - min(postfil)
            
            #convert spike train / instantaneous FR into smoothed & unsmoothed FR vectors
            smoothFR, _ , smoothocc = ps.tuning_curve(posxfil, B, dt, b = 2, l=2, smooth=True, SEM=False, occupancy=True)
            FR, _ , _ = ps.tuning_curve(posxfil, B, dt, b = 2, l=2, smooth=False, SEM=False, occupancy=True)

            for i, c in enumerate(cell_IDs):

                #calculate & store speed score for this cell's smoothed spike train
                B[:,i] = gaussian_filter1d(B[:,i],sigma)
                sscore, _ = stats.pearsonr(B[:,i],speed)
                shuffspeed_score = np.append(shuffspeed_score,sscore)
                
                #calculate & store speed stability score for this cell's smoothed spike train
                bin_pspikes = []
                for j in range(n_bin):
                    idx = bin_idx[j]
                    psscore, _ = stats.pearsonr(B[idx,i],speed[idx])
                    bin_pspikes = np.append(bin_pspikes, (psscore *  np.sum(B[idx,i])))
                
                sstabscore = np.sum(bin_pspikes) / np.sum(B[:,i])
                shuffspeedstab_score = np.append(shuffspeedstab_score,sstabscore)
                
                #calculate spatial sparsity score with smoothed FR 
                meanFRsqr = np.square(np.mean(smoothFR[:,i]))
                products = []
                for b in range(smoothFR.shape[0]):
                    binmeanFRsqr = np.square(smoothFR[b,i])
                    prob = smoothocc[b,i]/total_time
                    prod = prob * binmeanFRsqr
                    products = np.append(products,prod)
                sparsity = np.sum(products) / meanFRsqr
                shuffspatialsparseness = np.append(shuffspatialsparseness,sparsity)  
                
                # calculate spatial tuning coherence score with non-smoothed FR
                neighbors = find8adjacentElements(FR[:,i])
                meanFR_neighbors = []
                for b in range(FR.shape[0]):
                    meanFR_neigh = np.mean(neighbors[b])
                    meanFR_neighbors = np.append(meanFR_neighbors, meanFR_neigh)
                coherence, _ = stats.pearsonr(FR[:,i],meanFR_neighbors)
                if math.isnan(coherence):
                    shuffspatialcoherence = np.append(shuffspatialcoherence,0)
                else:
                    shuffspatialcoherence = np.append(shuffspatialcoherence,coherence)
                    
            shuffspeedscore[n,:] = shuffspeed_score #forms array (n_shuffreps, n_goodcells)
            shuffspeedstabscore[n,:] = shuffspeedstab_score #forms array (n_shuffreps, n_goodcells)
            shuffsparsityscores[n,:] = shuffspatialsparseness
            shuffspatialcoherencescores[n,:] = shuffspatialcoherence
            
            # for mice with dark trials...
            if (m in cohortb_mice):         
                
                FR, _ , _ = ps.tuning_curve_bytrial(posxfil, trial, B, dt, b = 2, smooth=True, normalize=True, occupancy=True)
                FR = FR[:stop_idx,:,:]
                n_trials = FR.shape[0]
                n_pos = FR.shape[1]
                n_cells = FR.shape[2]
                FR = (np.reshape(FR, (n_trials*n_pos, n_cells))).T
                
                for i, c in enumerate(cell_IDs[peak]):
                    sdx = (np.where(cell_IDs==c)[0][0]).astype(int)
                    autocorrelation = autocorr(FR[sdx,:],lags)
                    normauto = autocorrelation / autocorrelation[0]
                    preflag_height = normauto[maxpeak_locs[i].astype(int)]
                    shuffheights = np.append(shuffheights, preflag_height)

                shuffmaxpeak_heights[n,:] = shuffheights
            
        #save scores for all cells in a session in nested lists    
        d['shuffspeedscore'] = shuffspeedscore
        d['shuffspeedstabscore'] = shuffspeedstabscore
        d['shuffspatialcoherencescores'] = shuffspatialcoherencescores
        d['shuffsparsityscores'] = shuffsparsityscores
                
        #Get file names & save shuffled scores as npy files
        shufinstspeedscore_file = 'shufinstspeedscore_' + m + '_' + s + '.npy'
        shufspeedstabscore_file = 'shufspeedstabscore_' + m + '_' + s + '.npy'
        shufsparsityscore_file = 'shufsparsityscores_' + m + '_' + s + '.npy'
        shufspatialcoherencescore_file = 'shufspatialcoherencescores_' + m + '_' + s + '.npy'
        
        #np.save(save_folder + shufinstspeedscore_file, d['shuffspeedscore'])
        print('saved shuffled speed score data as npy file for mouse ' + m + ' session '+ s)
        
        #np.save(save_folder + shufspeedstabscore_file, d['shuffspeedstabscore'])
        print('saved shuffled speed stability score data as npy file for mouse ' + m + ' session '+ s)

        #np.save(save_folder + shufsparsityscore_file, d['shuffsparsityscores'])
        print('saved shuffled sparsity scores as npy file for mouse ' + m + ' session '+ s)

        #np.save(save_folder + shufspatialcoherencescore_file, d['shuffspatialcoherencescores'])
        print('saved shuffled spatial coherence scores as npy file for mouse ' + m + ' session '+ s)
        
        if m in cohortb_mice:
            #save scores for all cells in a session in nested lists    
            d['shuffmaxpeak_heights'] = shuffmaxpeak_heights

            #Get file names & save shuffled scores, grid cell boolean for spatial cells as npy files
            shufmaxpeak_heights_file = 'shufmaxpeak_heights__' + m + '_' + s + '.npy'

            #np.save(save_folder + shufmaxpeak_heights_file, d['shuffmaxpeak_heights'])
            print('saved shuffled max peak heights data as npy file for mouse ' + m + ' session '+ s)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# C:\Users\Python\AppData\Local\Temp\ipykernel_20048\3389816639.py:112: RuntimeWarning: invalid value encountered in divide
#   corr=np.correlate(xp,xp,'full')[len(x)-1:]/var/len(x)
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [36], in <cell line: 23>()
#     217     autocorrelation = autocorr(FR[sdx,:],lags)
#     218     normauto = autocorrelation / autocorrelation[0]
# --> 219     preflag_height = normauto[maxpeak_locs[i].astype(int)]
#     220     shuffheights = np.append(shuffheights, preflag_height)
#     222 shuffmaxpeak_heights[n,:] = shuffheights
#
# IndexError: index 150 is out of bounds for axis 0 with size 60

# %% [markdown]
# # Run shuffle & calculate scores for each rep for SM sessions

# %% [markdown]
# For Split Maze sessions as for RF sessions, we will classify speed-tuned cells and spatial cells. Given the multiple contexts in the SM task and spatial maps for each context, I calculated the spatial tuning curve for Block A (trials 20-80) only and sparsity and coherence scores for that period only to classify spatial cells. For SM sessions, we also calculate the peakiness of the dark FR autocorrelation on each shuffle to differentiate grid from non-grid spatial cells as above.

# %%
''' Load in the SM sessions only'''
# Define mice, sessions for particular cohorts
#mice , mice_ind, _  = np.intersect1d(all_mice,(np.union1d(cohorta_mice, cohortb_mice)), return_indices = True) # RF mice
mice , mice_ind, _  = np.intersect1d(all_mice,np.union1d(cohortc_mice, cohortd_mice), return_indices = True) # SM mice

# If you found the intersection 
sessions = []
for i in mice_ind:
    sessions.append(all_sessions[i])

# Make a dict to hold data
data = {}

for session, m in zip(sessions, mice):
    data[m] = {}
    
    for s in session:
        data[m][s] = {}

# %%
''' Calculate 100x Shuffled Scores for each Cell in all SM Sessions 

Shuffle speed & speed stability scores are used to classify speed-tuning. 
Shuffle spatial sparsity & coherence scores are used to classify position-tuning, identifying spatial cells.
Shuffle dark FR autocorrelation max peak height at the same lag as the actual dark max peak is used to differentiate
grid from non-grid spatial cells. 

Expected run time is hours per session.

'''
n_rep = 100 # number of shuffles
sigma = 20  # smoothing factor for speed & speed stability scores
n_bin = 8 #n position bins considered for speed stability score
track_length = 400 #cm
bins = np.arange(0,track_length + (track_length/n_bin),(track_length/n_bin))
n_dark = 20 #trials
lags = np.arange(0,801,1)

save_folder = 'C:/Users/Python/Desktop/LocalData/shuffscores/' #adjust path 
dataload_folder = 'C:/Users/Python/Desktop/LocalData/filtered/'#adjust path to output of Import & Filter notebook

for m, session in zip(mice,sessions):
    for s in tdqm(session):
        d = data[m][s]
        
        #load in data
        rawdata_file = 'RAW_' + m + '_' + s + '.npy'
        behavior_file = 'BEHAVIOR_' + m + '_' + s + '.npy'
        spikes_file = 'SPIKES_' + m + '_' + s +'.npy'
            
        raw = np.load(dataload_folder + rawdata_file, allow_pickle=True)
        behaviorfil = np.load(dataload_folder + behavior_file, allow_pickle=False)
        Y = np.load(dataload_folder + spikes_file, allow_pickle=False) #pre-filtered for speeds >2cm/s, position-corrected spikes
        
        rawspeed = raw.item().get('speed')
        speed = behaviorfil[:,1]
        
        sp = raw.item().get('sp')
        spiket = sp['st'].copy()
        cluster_id = sp['clu'].copy()
        cell_IDs = raw.item().get('cellsfil')
        posx = raw.item().get('posx')
        post = raw.item().get('post')
        
        dt = np.unique(np.round(np.diff(post),4))
        if len(dt) > 1: # discard duplicate frame entries if they occurred
            dt = dt[dt != 0]
            dt_to_trash = np.where(np.diff(post) == 0)[0]
        else:
            dt_to_trash = [] 
            
        posxfil = behaviorfil[:,0]
        trial = behaviorfil[:,2]
        trials = np.unique(trial)
        postfil = behaviorfil[:,3]
        
        # filter spikes & position frames by speed < 2cm/s or out of track limits 
        speed_to_trash = find(rawspeed < 2)
        pos_to_trash = find((posx < 0) | (posx > 400))
        trash_idx = np.unique(np.concatenate((dt_to_trash, speed_to_trash, pos_to_trash)))
        keep_idx = np.setdiff1d(np.arange(len(rawspeed)), trash_idx)
        
        #get dark-only, normalized, smoothed spatial map & reshape into continuous vector for each cell
        FR, _ , _ = ps.tuning_curve_bytrial(posxfil, trial, Y, dt, b = 2, smooth=True, normalize=True, occupancy=True)
        stop_idx = np.where(trials == n_dark)[0][0]
        FR = FR[:stop_idx,:,:]
        n_trials = FR.shape[0]
        n_pos = FR.shape[1]
        n_cells = FR.shape[2]
        FR = (np.reshape(FR, (n_trials*n_pos, n_cells))).T
        print(FR.shape)
        
        #find max autocorrelation peaks for all cells; store height & prom of most prominent peak
        peak = [] # boolean if peak found
        maxpeak_locs = [] #stored lag of max peak if peak exist
        maxpeak_heights = [] # stored height of max peak, otherwise 0 if not exist
        maxpeak_proms = [] # stored prominence of max peak, otherwise 0 if not exist
        for i, c in enumerate(cell_IDs):
            sdx = np.where(cell_IDs == c)[0][0]
            autocorrelation = autocorr(FR[sdx,:],lags)
            normauto = autocorrelation / autocorrelation[0]
            peaks, properties = find_peaks(normauto, width = 10, height = 0.10, prominence = 0.15)
            proms = properties["prominences"]
            heights = properties["peak_heights"]

            if peaks.size > 0:
                peak = np.append(peak,1)
                maxpeak_locs = np.append(maxpeak_locs, peaks[np.argmax(proms)])
                maxpeak_heights = np.append(maxpeak_heights, heights[np.argmax(proms)])
                maxpeak_proms = np.append(maxpeak_proms, proms[np.argmax(proms)])
            else:
                peak = np.append(peak,0)
                maxpeak_heights = np.append(maxpeak_heights,0)
                maxpeak_proms = np.append(maxpeak_proms,0)
                
        peak = peak.astype(bool)
        
        # find indices of spike corresponding to 8 x 50cm bins along the track based on filtered position
        bin_idx = []
        for i in range(n_bin):
            if i == (n_bin - 1):
                idx = np.where((posxfil >= bins[i]) & (posxfil <= bins[i + 1]))[0]
            else:
                idx = np.where((posxfil >= bins[i]) & (posxfil < bins[i + 1]))[0]
            bin_idx.append(idx)
        
        #find start and end of the Block A trials
        start_idx = (np.where(trial == 20)[0][0]).astype(int) # trial is zero-indexed, 20 full dark trials
        end_idx = (np.where(trial == 79)[0][-1]).astype(int) # get indices of all 60 context_a trials that follow dark
            
        #calculate & save shuffled speed scores
        shuffspeedscore = np.zeros((n_rep, len(cell_IDs)))
        shuffspeedstabscore = np.zeros((n_rep, len(cell_IDs)))
        shuffspatialacoherencescores = np.zeros((n_rep,len(cell_IDs)))
        shuffsparsityascores = np.zeros((n_rep,len(cell_IDs)))
        shuffmaxpeak_heights = np.zeros((n_rep, len(cell_IDs[peak])))

        for n in tdqm(range(0, n_rep)):
            
            shuffspeed_score = []
            shuffspeedstab_score = []
            shuffspatialasparseness = []
            shuffspatialacoherence = []
            shuffheights = []
            
            B = np.zeros((len(rawspeed), len(cell_IDs))) # reset empty shuffled FR matrix
            
            for i, c in enumerate(cell_IDs):
                sdx = (np.where(cell_IDs==c)[0][0]).astype(int)
                
                #get actual spike times for each cell
                st = spiket[cluster_id == c]
                st = st[(st >= min(post)) & (st <= max(post))]

                #get shuffle times
                st_shuf = st - min(post)
                total_time = max(post) - min(post)
                add = np.random.uniform(0.02,total_time,1)
                st_shuf = (st_shuf + add) % total_time
                st_shuf = st_shuf + min(post)
                                                        
                #get unfiltered spike train
                spike_ct = np.zeros_like(post)
                spike_idx = np.digitize(st_shuf,post) #obs corresponding to where each shuffled spike occurs

                idx, cts = np.unique(spike_idx, return_counts = True)
                spike_ct[idx] = cts
                B[:,i] = spike_ct

                #check for & interpolate any missing values; smooth if necessary
                if sum(np.isnan(B[:,i])) > 0:
                    B[:,i] = get.nan_interp(B[:,i])  

            #apply filter spike train by speed & posx errors
            B = B[keep_idx,:]
            
            #select the Block A spike train
            atotal_time = max(postfil[start_idx:end_idx]) - min(postfil[start_idx:end_idx])
            A = B[start_idx:end_idx, :]
            aposxfil = posxfil[start_idx:end_idx]
            
            #convert spike train / instantaneous FR into smoothed & unsmoothed FR vectors
            asmoothFR, _, asmoothocc = ps.tuning_curve(aposxfil, A, dt, b = 2, l=2, smooth=True, SEM=False, occupancy=True)
            aFR, _ , _ = ps.tuning_curve(aposxfil, A, dt, b = 2, l = 2, smooth=False, SEM=False, occupancy=True)
            
            #calculate dark FR 
            FR, _ , _ = ps.tuning_curve_bytrial(posxfil, trial, B, dt, b = 2, smooth=True, normalize=True, occupancy=True)
            stop_idx = np.where(trials == n_dark)[0][0]
            FR = FR[:stop_idx,:,:]
            n_trials = FR.shape[0]
            n_pos = FR.shape[1]
            n_cells = FR.shape[2]
            FR = (np.reshape(FR, (n_trials*n_pos, n_cells))).T
            print(FR.shape)

            for i, c in enumerate(cell_IDs):

                #calculate & store speed score for this cell's smoothed spike train
                B[:,i] = gaussian_filter1d(B[:,i],sigma)
                sscore, _ = stats.pearsonr(B[:,i],speed)
                shuffspeed_score = np.append(shuffspeed_score,sscore)
                
                #calculate & store speed stability score for this cell's smoothed spike train
                bin_pspikes = []
                for j in range(n_bin):
                    idx = bin_idx[j]
                    psscore, _ = stats.pearsonr(B[idx,i],speed[idx])
                    bin_pspikes = np.append(bin_pspikes, (psscore *  np.sum(B[idx,i])))
                
                sstabscore = np.sum(bin_pspikes) / np.sum(B[:,i])
                shuffspeedstab_score = np.append(shuffspeedstab_score,sstabscore)
                
                #calculate sparsity with smoothed FR in Context A
                meanFRsqr = np.square(np.mean(asmoothFR[:,i]))
                products = []
                for b in range(asmoothFR.shape[0]):
                    binmeanFRsqr = np.square(asmoothFR[b,i])
                    prob = asmoothocc[b,i]/atotal_time
                    prod = prob * binmeanFRsqr
                    products = np.append(products,prod)
                asparsity = np.sum(products) / meanFRsqr
                    
                shuffspatialasparseness = np.append(shuffspatialasparseness,asparsity)  

                # calculate spatial tuning coherence score with non-smoothed FR
                neighbors = find8adjacentElements(aFR[:,i])
                meanFR_neighbors = []
                for b in range(aFR.shape[0]):
                    meanFR_neigh = np.mean(neighbors[b])
                    meanFR_neighbors = np.append(meanFR_neighbors, meanFR_neigh)
                acoherence, _ = stats.pearsonr(aFR[:,i],meanFR_neighbors)
                if math.isnan(acoherence):
                    shuffspatialacoherence = np.append(shuffspatialacoherence,0)
                else:
                    shuffspatialacoherence = np.append(shuffspatialacoherence,acoherence)
                  
                # if cell had a peak in its dark FR autocorrelation, find shuffle autocorrelation height at that same lag
                if c in cell_IDs[peak]:
                    cdx = (np.where(cell_IDs[peak] == c)[0][0]).astype(int)
                    sdx = np.where(cell_IDs == c)[0][0]
                    autocorrelation = autocorr(FR[sdx,:],lags)
                    normauto = autocorrelation / autocorrelation[0]
                    preflag_height = normauto[maxpeak_locs[cdx].astype(int)]
                    shuffheights = np.append(shuffheights, preflag_height)
                    
            shuffspeedscore[n,:] = shuffspeed_score #forms array (n_shuffreps, n_goodcells)
            shuffspeedstabscore[n,:] = shuffspeedstab_score #forms array (n_shuffreps, n_goodcells)
            shuffsparsityascores[n,:] = shuffspatialasparseness #forms array (n_shuffreps, n_goodcells)
            shuffspatialacoherencescores[n,:] = shuffspatialacoherence #forms array (n_shuffreps, n_goodcells)
            shuffmaxpeak_heights[n,:] = shuffheights
            
        #save scores for all cells in a session in nested lists    
        d['shuffspeedscore'] = shuffspeedscore
        d['shuffspeedstabscore'] = shuffspeedstabscore
        d['shuffspatialacoherencescores'] = shuffspatialacoherencescores
        d['shuffsparsityascores'] = shuffsparsityascores
        d['shuffmaxpeak_heights'] = shuffmaxpeak_heights
                           
        #Get file names & save shuffled scores as npy files
        shufinstspeedscore_file = 'shufinstspeedscore_' + m + '_' + s + '.npy'
        shufspeedstabscore_file = 'shufspeedstabscore_' + m + '_' + s + '.npy'
        shufsparsityascore_file = 'shufsparsityascores_' + m + '_' + s + '.npy'
        shufspatialacoherencescore_file = 'shufspatialacoherencescores_' + m + '_' + s + '.npy'
        shufmaxpeak_heights_file = 'shufmaxpeak_heights__' + m + '_' + s + '.npy'
        
        #np.save(save_folder + shufinstspeedscore_file, d['shuffspeedscore'])
        print('saved shuffled speed score data as npy file for mouse ' + m + ' session '+ s)
        
        #np.save(save_folder + shufspeedstabscore_file, d['shuffspeedstabscore'])
        print('saved shuffled speed stability score data as npy file for mouse ' + m + ' session '+ s)

        #np.save(save_folder + shufsparsityascore_file, d['shuffsparsityascores'])
        print('saved shuffled Context A sparsity scores as npy file for mouse ' + m + ' session '+ s)

        #np.save(save_folder + shufspatialacoherencescore_file, d['shuffspatialacoherencescores'])
        print('saved shuffled Context A spatial coherence scores as npy file for mouse ' + m + ' session '+ s)
        
        #np.save(save_folder + shufmaxpeak_heights_file, d['shuffmaxpeak_heights'])
        print('saved shuffled max peak heights data as npy file for mouse ' + m + ' session '+ s)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# (216, 3600)
# C:\Users\Python\AppData\Local\Temp\ipykernel_20048\3389816639.py:112: RuntimeWarning: invalid value encountered in divide
#   corr=np.correlate(xp,xp,'full')[len(x)-1:]/var/len(x)
#   0%|          | 0/100 [00:00<?, ?it/s]
# (216, 3600)
# C:\Users\Python\AppData\Local\Temp\ipykernel_20048\3248375995.py:202: RuntimeWarning: invalid value encountered in scalar divide
#   asparsity = np.sum(products) / meanFRsqr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [49], in <cell line: 23>()
#     165 aFR, _ , _ = ps.tuning_curve(aposxfil, A, dt, b = 2, l = 2, smooth=False, SEM=False, occupancy=True)
#     167 #calculate dark FR
# --> 168 FR, _ , _ = ps.tuning_curve_bytrial(posxfil, trial, B, dt, b = 2, smooth=True, normalize=True, occupancy=True)
#     169 stop_idx = np.where(trials == n_dark)[0][0]
#     170 FR = FR[:stop_idx,:,:]
#
# File ~\Desktop\GitHub\Herber2024\pipeline\process_spikes.py:280, in tuning_curve_bytrial(x, trial, Y, dt, b, smooth, normalize, occupancy)
#     278     occ[i, j, :] = 0
#     279 else:
# --> 280     spike_ct = np.sum(Y[idx, :], axis=0)
#     281     occupancy = dt * np.sum(idx)
#     282     occ[i, j, :] = occupancy
#
# KeyboardInterrupt:
